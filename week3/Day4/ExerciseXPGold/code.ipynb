# %%
# Exercise 1: Concatenate list

a=[1, 2, 3]
b=[5, 6, 7]
# Add all elements from list 'b' to the end of list 'a'
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 5, 6, 7]

# %%
# Exercise 2: Range of numbers
# Create a loop that goes from 1500 to 2500 and prints all multiples of 5 and 7.

for num in range(1500, 25001):
    if num % 5 == 0 and num % 7 == 0:
        print(num)
# Out:
# 1505
# 1540
# 1575
# 1610
# 1645
# 1680
# 1715
# 1750
# 1785
# 1820
# 1855
# 1890
# 1925
# 1960
# 1995
# 2030
# 2065
# 2100
# 2135
# 2170
# 2205
# 2240
# 2275
# 2310
# 2345
# 2380
# 2415
# 2450
# 2485
# 2520
# 2555
# 2590
# 2625
# 2660
# 2695
# 2730
# 2765
# 2800
# 2835
# 2870
# 2905
# 2940
# 2975
# 3010
# 3045
# 3080
# 3115
# 3150
# 3185
# 3220
# 3255
# 3290
# 3325
# 3360
# 3395
# 3430
# 3465
# 3500
# 3535
# 3570
# 3605
# 3640
# 3675
# 3710
# 3745
# 3780
# 3815
# 3850
# 3885
# 3920
# 3955
# 3990
# 4025
# 4060
# 4095
# 4130
# 4165
# 4200
# 4235
# 4270
# 4305
# 4340
# 4375
# 4410
# 4445
# 4480
# 4515
# 4550
# 4585
# 4620
# 4655
# 4690
# 4725
# 4760
# 4795
# 4830
# 4865
# 4900
# 4935
# 4970
# 5005
# 5040
# 5075
# 5110
# 5145
# 5180
# 5215
# 5250
# 5285
# 5320
# 5355
# 5390
# 5425
# 5460
# 5495
# 5530
# 5565
# 5600
# 5635
# 5670
# 5705
# 5740
# 5775
# 5810
# 5845
# 5880
# 5915
# 5950
# 5985
# 6020
# 6055
# 6090
# 6125
# 6160
# 6195
# 6230
# 6265
# 6300
# 6335
# 6370
# 6405
# 6440
# ...

# %%
# Exercise 3: Check the index

names = ['Samus', 'Cortana', 'V', 'Link', 'Mario', 'Cortana', 'Samus']
username=input('Enter your name.')

if username in names:
    print(f"The index of the first occurrence of {username} is {names.index(username)}")
else:
    print("Name not found in the list.")
# Out:
# The index of the first occurrence of V is 2

# %%
# Exercise 4: Greatest Number

x=int(input('Enter a first number'))
y=int(input('Enter a second number'))
z=int(input('Enter a third number'))

if x >= y and x >= z:
    print(f'The greatest number is {x}')
elif y >=x and y>= z:
    print(f'The greatest number is {y}')
else:
    print(f'The greatest number is {z}')
# Out:
# The greatest number is 54

# %%
# Exercise 5: The Alphabet

alphabet="abcdefghijklmnopqrstuvwxyz"
vowels="aeiou"

for letter in alphabet:
    if letter in vowels:
        print(f"{letter} is a vowel.")
    else:
        print(f"{letter} is a consonant.")

# %%
# Exercise 6: Words and letters

words=[]
for i in range(7):
    word=input(f'Enter a word {i+1}:')
    words.append(word)

letter=input('Enter a single character')

for word in words:
    if letter in word:
        print(f"In '{word}', the letter '{letter}' appears at index {word.index(letter)}.")
    else:
        print(f"The letter '{letter}' does not exist in the word '{word}'.")
# Out:
# In 'baby', the letter 'y' appears at index 3.
# The letter 'y' does not exist in the word 'child'.
# The letter 'y' does not exist in the word 'house'.
# The letter 'y' does not exist in the word 'car'.
# The letter 'y' does not exist in the word 'tiktok'.
# In 'yoghurt', the letter 'y' appears at index 0.
# In 'python', the letter 'y' appears at index 1.

# %%
# Exercise 7: Min, Max, Sum

numbers = list(range(1, 1000001))

print(f"Minimum: {min(numbers)}")
print(f"Maximum: {max(numbers)}")
print(f"Sum: {sum(numbers)}")
# Out:
# Minimum: 1
# Maximum: 1000000
# Sum: 500000500000

# %%
# Exercise 8 : List and Tuple

input_str = input("Enter comma-separated numbers: ")
numbers_list = input_str.split(",")
numbers_tuple = tuple(numbers_list)

print(numbers_list)
print(numbers_tuple)
# Out:
# ['34', '54', '56', '78']
# ('34', '54', '56', '78')

# %%
# Exercise 9 : Random number

import random

wins = 0
losses = 0

while True:
    user_input = input("Guess a number from 1 to 9 (or type 'quit' to exit): ")
    if user_input.lower() == 'quit':
        break
    if not user_input.isdigit() or not (1 <= int(user_input) <= 9):
        print("Please enter a valid number from 1 to 9.")
        continue

    user_guess = int(user_input)
    rand_num = random.randint(1, 9)

    if user_guess == rand_num:
        print("Winner!")
        wins += 1
    else:
        print(f"Better luck next time. The number was {rand_num}.")
        losses += 1

print(f"Total games won: {wins}")
print(f"Total games lost: {losses}")
